# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# functions needed for pr_auc_score()
from sklearn.metrics import auc, precision_recall_curve
from sklearn import metrics

# functions needed for imbalanced_cross_validation_score()
from sklearn.model_selection import StratifiedKFold

# sampler objects
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler

# Classification models to compare
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB # naive bayes
from sklearn.neighbors import KNeighborsClassifier # KNN
from sklearn.svm import SVC # SVM
from imblearn.ensemble import BalancedBaggingClassifier

from sklearn import preprocessing 

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
def pr_auc_score(clf, x, y):
    '''
        This function computes area under the precision-recall curve. 
    '''
      
    precisions, recalls,_ = precision_recall_curve(y, clf.predict_proba(x)[:,1], pos_label=1)
    
    return auc(recalls, precisions)

# %%
def Confusion_matrix(clf, x, y):
    cm = metrics.confusion_matrix(y, clf.predict(x))
    return (cm[0][0], cm[0][1], cm[1][0], cm[1][1])

# %%
def imbalanced_cross_validation_score(clf, x, y, cv, scoring, sampler):
    '''
        This function computes the cross-validation score of a given 
        classifier using a choice of sampling function to mitigate 
        the class imbalance, and stratified k-fold sampling.
        
        The first five arguments are the same as 
        sklearn.model_selection.cross_val_score.
        
        - clf.predict_proba(x) returns class label probabilities
        - clf.fit(x,y) trains the model
        
        - x = data
        
        - y = labels
        
        - cv = the number of folds in the cross validation
        
        - scoring(classifier, x, y) returns a float
        
        The last argument is a choice of random sampler: an object 
        similar to the sampler objects available from the python 
        package imbalanced-learn. In particular, this 
        object needs to have the method:
        
        sampler.fit_sample(x,y)
        
        See http://contrib.scikit-learn.org/imbalanced-learn/
        for more details and examples of other sampling objects 
        available.  
    
    '''
    
    cv_score = 0.
    train_score = 0.
    test_score = 0.
    TP = 0
    FP = 0
    FN = 0
    TN = 0
    
    # stratified k-fold creates folds with the same ratio of positive 
    # and negative samples as the entire dataset.
    
    skf = StratifiedKFold(n_splits=cv, random_state=0, shuffle=False)
    
    for train_idx, test_idx in skf.split(x,y):
        
        xfold_train_sampled, yfold_train_sampled = sampler.fit_sample(x[train_idx],y[train_idx])
        clf.fit(xfold_train_sampled, yfold_train_sampled)
        
        TP_train, FP_train, FN_train, TN_train = scoring(clf, xfold_train_sampled, yfold_train_sampled)
        TP_test, FP_test, FN_test, TN_test  = scoring(clf, x[test_idx], y[test_idx])
        
        print("Train FP: {0} Train FN: {1}; Test FP: {2} Test FN: {3}".format(FP_train, FN_train, FP_test, FN_test))
        
        TP += TP_test
        FP += FP_test
        FN += FN_test
        TN += TN_test
        

    ave_tp = TP/cv
    ave_fp = FP/cv
    ave_fn = FN/cv
    ave_tn = TN/cv
    
    
    sensitivity = ave_tp/(ave_tp + ave_fn)
    specificity = ave_tn/(ave_fp + ave_tn)
    
    g_mean = math.sqrt(sensitivity * specificity)
    mcc = (ave_tp * ave_tn - ave_fp * ave_fn)/math.sqrt((ave_tp + ave_fp) * (ave_tp + ave_fn) * (ave_tn + ave_fp) * (ave_tn + ave_fn))
    
    values = [sensitivity, specificity, g_mean, mcc]
    
        
    return values

# %%
x_train_o = pd.read_csv('financial_data.csv')
y_train_o = pd.read_csv('revealed_businesses.csv')

x_test_o = pd.read_csv("testing_data.csv")

x_train_o.replace('?', np.nan, inplace=True)
x_train_o = x_train_o.astype('float64')


x_test_o.replace('?', np.nan, inplace=True)
x_test_o = x_test_o.astype('float64')

data_all = x_train_o.merge(y_train_o, on='Var1', how = 'left')

data_nolabel = data_all[data_all.Var66.isnull()]
data_label = data_all[data_all.Var66.notnull()]

data_nolabel_v = data_nolabel.drop(columns=['Var1', 'Var66'])
data_nolabel_id = data_nolabel['Var1']

data_label_v = data_label.drop(columns=['Var1', 'Var66'])
data_label_id = data_label['Var1']

data_nolabel_v_f = data_nolabel_v.fillna(data_nolabel_v.mean())
data_label_v_f = data_label_v.fillna(data_label_v.mean())

# %%
X = data_label_v_f.values
y = data_label['Var66'].values

# %%
x = preprocessing.MinMaxScaler().fit_transform(X)

# %%
clfs={
    'gnb': GaussianNB(),
    'svm': SVC(),
    'lr':  LogisticRegression(),
    'rfc': RandomForestClassifier(),
    'et': ExtraTreesClassifier(),
    'ada': AdaBoostClassifier(),
    'ml': MLPClassifier(),
    'bb': BalancedBaggingClassifier(base_estimator = RandomForestClassifier(criterion='gini'), 
                                          n_estimators = 15, bootstrap = True)
    
}
cv = 10
for clf_name in clfs:
    print("Classifier: {0}".format(clf_name))
    # Logistic regression score with Random Over-sampling
    print("Random over-sampling")
    values = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, Confusion_matrix, RandomOverSampler())
    print("sensitivity: %.2f | specificity: %.2f | g_mean: %.2f | mcc: %.2f"%(values[0], values[1], values[2], values[3]))

    # Logistic regression score with SMOTE
    print("SMOTE over-sampling")
    values = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, Confusion_matrix, SMOTE())
    print("sensitivity: %.2f | specificity: %.2f | g_mean: %.2f | mcc: %.2f"%(values[0], values[1], values[2], values[3]))

    # Logistic regression score with ADASYN
    print("ADASYN over-sampling")
    values = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, Confusion_matrix, ADASYN())
    print("sensitivity: %.2f | specificity: %.2f | g_mean: %.2f | mcc: %.2f"%(values[0], values[1], values[2], values[3]))

    # Logistic regression score with Random Under Sampling
    print("Random under-sampling")
    values = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, Confusion_matrix, RandomUnderSampler())
    print("sensitivity: %.2f | specificity: %.2f | g_mean: %.2f | mcc: %.2f"%(values[0], values[1], values[2], values[3]))

    print("-"*70)
    print()
# Out:
# Classifier: gnb
# Random over-sampling
# Train FP: 3880 Train FN: 27; Test FP: 432 Test FN: 1
# Train FP: 3887 Train FN: 46; Test FP: 424 Test FN: 1
# Train FP: 3846 Train FN: 89; Test FP: 425 Test FN: 2
# Train FP: 3873 Train FN: 69; Test FP: 428 Test FN: 0
# Train FP: 3863 Train FN: 105; Test FP: 435 Test FN: 2
# Train FP: 3833 Train FN: 101; Test FP: 438 Test FN: 1
# Train FP: 3822 Train FN: 115; Test FP: 422 Test FN: 2
# Train FP: 3819 Train FN: 51; Test FP: 427 Test FN: 1
# Train FP: 3866 Train FN: 54; Test FP: 427 Test FN: 4
# Train FP: 1243 Train FN: 1364; Test FP: 153 Test FN: 8
# Train FP: 1196 Train FN: 1502; Test FP: 140 Test FN: 5
# Train FP: 1290 Train FN: 1404; Test FP: 136 Test FN: 7
# Train FP: 1159 Train FN: 1578; Test FP: 127 Test FN: 7
# sensitivity: 0.98 | specificity: 0.07 | g_mean: 0.26 | mcc: 0.12
# SMOTE over-sampling
# Train FP: 1307 Train FN: 1349; Test FP: 152 Test FN: 9
# Train FP: 1317 Train FN: 1436; Test FP: 147 Test FN: 4
# Train FP: 1325 Train FN: 1354; Test FP: 147 Test FN: 4
# Train FP: 1273 Train FN: 1427; Test FP: 152 Test FN: 6
# Train FP: 1252 Train FN: 1412; Test FP: 144 Test FN: 8
# Train FP: 1278 Train FN: 1422; Test FP: 125 Test FN: 6
# Train FP: 1346 Train FN: 1286; Test FP: 161 Test FN: 8
# Train FP: 1234 Train FN: 1487; Test FP: 139 Test FN: 6
# Train FP: 1304 Train FN: 1403; Test FP: 129 Test FN: 7
# Train FP: 1260 Train FN: 1453; Test FP: 138 Test FN: 7
# sensitivity: 0.98 | specificity: 0.07 | g_mean: 0.26 | mcc: 0.12
# ADASYN over-sampling
# Train FP: 1339 Train FN: 1263; Test FP: 153 Test FN: 8
# Train FP: 1315 Train FN: 1464; Test FP: 148 Test FN: 5
# Train FP: 1309 Train FN: 1435; Test FP: 146 Test FN: 3
# Train FP: 1270 Train FN: 1465; Test FP: 156 Test FN: 6
# Train FP: 1289 Train FN: 1354; Test FP: 150 Test FN: 7
# Train FP: 1275 Train FN: 1502; Test FP: 123 Test FN: 6
# Train FP: 1294 Train FN: 1341; Test FP: 160 Test FN: 8
# Train FP: 1254 Train FN: 1519; Test FP: 139 Test FN: 6
# Train FP: 1285 Train FN: 1410; Test FP: 126 Test FN: 7
# Train FP: 1284 Train FN: 1433; Test FP: 140 Test FN: 7
# sensitivity: 0.98 | specificity: 0.07 | g_mean: 0.26 | mcc: 0.13
# Random under-sampling
# Train FP: 41 Train FN: 63; Test FP: 143 Test FN: 9
# Train FP: 45 Train FN: 68; Test FP: 125 Test FN: 5
# Train FP: 47 Train FN: 57; Test FP: 142 Test FN: 4
# Train FP: 43 Train FN: 66; Test FP: 124 Test FN: 6
# Train FP: 56 Train FN: 50; Test FP: 159 Test FN: 8
# Train FP: 55 Train FN: 64; Test FP: 188 Test FN: 6
# Train FP: 64 Train FN: 60; Test FP: 186 Test FN: 6
# Train FP: 51 Train FN: 53; Test FP: 185 Test FN: 8
# Train FP: 39 Train FN: 70; Test FP: 104 Test FN: 10
# Train FP: 52 Train FN: 57; Test FP: 198 Test FN: 7
# sensitivity: 0.98 | specificity: 0.06 | g_mean: 0.24 | mcc: 0.10
# ----------------------------------------------------------------------
#
# Classifier: rfc
# Random over-sampling
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 14
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 12
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 15
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 10
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 13
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 11
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 12
# sensitivity: 0.97 | specificity: 0.88 | g_mean: 0.93 | mcc: 0.47
# SMOTE over-sampling
# Train FP: 1 Train FN: 0; Test FP: 8 Test FN: 12
# Train FP: 2 Train FN: 0; Test FP: 9 Test FN: 9
# Train FP: 1 Train FN: 4; Test FP: 7 Test FN: 10
# Train FP: 1 Train FN: 4; Test FP: 4 Test FN: 10
# Train FP: 3 Train FN: 1; Test FP: 6 Test FN: 9
# Train FP: 1 Train FN: 2; Test FP: 6 Test FN: 8
# Train FP: 2 Train FN: 2; Test FP: 5 Test FN: 12
# Train FP: 0 Train FN: 3; Test FP: 2 Test FN: 11
# Train FP: 1 Train FN: 1; Test FP: 5 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 11
# sensitivity: 0.98 | specificity: 0.55 | g_mean: 0.73 | mcc: 0.44
# ADASYN over-sampling
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 7 Test FN: 11
# Train FP: 2 Train FN: 3; Test FP: 9 Test FN: 10
# Train FP: 1 Train FN: 1; Test FP: 4 Test FN: 12
# Train FP: 0 Train FN: 3; Test FP: 3 Test FN: 9
# Train FP: 1 Train FN: 0; Test FP: 4 Test FN: 8
# Train FP: 3 Train FN: 0; Test FP: 4 Test FN: 14
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 10
# Train FP: 2 Train FN: 1; Test FP: 2 Test FN: 11
# Train FP: 2 Train FN: 0; Test FP: 3 Test FN: 11
# sensitivity: 0.98 | specificity: 0.58 | g_mean: 0.75 | mcc: 0.44
# Random under-sampling
# Train FP: 1 Train FN: 3; Test FP: 102 Test FN: 8
# Train FP: 1 Train FN: 1; Test FP: 115 Test FN: 2
# Train FP: 0 Train FN: 3; Test FP: 101 Test FN: 6
# Train FP: 0 Train FN: 7; Test FP: 115 Test FN: 7
# Train FP: 2 Train FN: 2; Test FP: 110 Test FN: 5
# Train FP: 0 Train FN: 3; Test FP: 99 Test FN: 5
# Train FP: 0 Train FN: 2; Test FP: 133 Test FN: 3
# Train FP: 0 Train FN: 4; Test FP: 119 Test FN: 2
# Train FP: 0 Train FN: 3; Test FP: 91 Test FN: 5
# Train FP: 0 Train FN: 1; Test FP: 127 Test FN: 4
# sensitivity: 0.99 | specificity: 0.10 | g_mean: 0.31 | mcc: 0.21
# ----------------------------------------------------------------------
#
# Classifier: et
# Random over-sampling
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 16
# Train FP: 0 Train FN: 0; Test FP: 3 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 16
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 16
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 15
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 17
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 15
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 17
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 17
# sensitivity: 0.97 | specificity: 0.73 | g_mean: 0.84 | mcc: 0.25
# SMOTE over-sampling
# Train FP: 0 Train FN: 0; Test FP: 3 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 11 Test FN: 14
# Train FP: 0 Train FN: 0; Test FP: 5 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 5 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 4 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 16
# Train FP: 0 Train FN: 0; Test FP: 8 Test FN: 10
# Train FP: 0 Train FN: 0; Test FP: 9 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 4 Test FN: 11
# sensitivity: 0.97 | specificity: 0.45 | g_mean: 0.66 | mcc: 0.34
# ADASYN over-sampling
# Train FP: 0 Train FN: 0; Test FP: 3 Test FN: 15
# Train FP: 0 Train FN: 0; Test FP: 7 Test FN: 11
# Train FP: 0 Train FN: 0; Test FP: 5 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 5 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 9 Test FN: 11
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 7
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 12
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 3 Test FN: 13
# sensitivity: 0.98 | specificity: 0.51 | g_mean: 0.71 | mcc: 0.39
# Random under-sampling
# Train FP: 0 Train FN: 0; Test FP: 90 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 90 Test FN: 3
# Train FP: 0 Train FN: 0; Test FP: 82 Test FN: 3
# Train FP: 0 Train FN: 0; Test FP: 108 Test FN: 5
# Train FP: 0 Train FN: 0; Test FP: 107 Test FN: 8
# Train FP: 0 Train FN: 0; Test FP: 100 Test FN: 4
# Train FP: 0 Train FN: 0; Test FP: 103 Test FN: 7
# Train FP: 0 Train FN: 0; Test FP: 97 Test FN: 5
# Train FP: 0 Train FN: 0; Test FP: 108 Test FN: 3
# Train FP: 0 Train FN: 0; Test FP: 99 Test FN: 5
# sensitivity: 0.99 | specificity: 0.11 | g_mean: 0.32 | mcc: 0.21
# ----------------------------------------------------------------------
#
# Classifier: ada
# Random over-sampling
# Train FP: 333 Train FN: 228; Test FP: 36 Test FN: 8
# Train FP: 393 Train FN: 250; Test FP: 41 Test FN: 4
# Train FP: 361 Train FN: 211; Test FP: 52 Test FN: 6
# Train FP: 357 Train FN: 198; Test FP: 44 Test FN: 8
# Train FP: 377 Train FN: 255; Test FP: 48 Test FN: 6
# Train FP: 338 Train FN: 209; Test FP: 36 Test FN: 8
# Train FP: 353 Train FN: 210; Test FP: 52 Test FN: 5
# Train FP: 337 Train FN: 152; Test FP: 38 Test FN: 4
# Train FP: 368 Train FN: 224; Test FP: 38 Test FN: 5
# Train FP: 323 Train FN: 311; Test FP: 35 Test FN: 8
# sensitivity: 0.99 | specificity: 0.20 | g_mean: 0.45 | mcc: 0.32
# SMOTE over-sampling
# Train FP: 243 Train FN: 239; Test FP: 32 Test FN: 9
# Train FP: 254 Train FN: 278; Test FP: 38 Test FN: 7
# Train FP: 267 Train FN: 257; Test FP: 39 Test FN: 7
# Train FP: 242 Train FN: 266; Test FP: 37 Test FN: 6
# Train FP: 263 Train FN: 310; Test FP: 26 Test FN: 9
# Train FP: 258 Train FN: 270; Test FP: 17 Test FN: 10
# Train FP: 242 Train FN: 318; Test FP: 34 Test FN: 10
# Train FP: 278 Train FN: 295; Test FP: 27 Test FN: 5
# Train FP: 265 Train FN: 329; Test FP: 37 Test FN: 6
# Train FP: 266 Train FN: 308; Test FP: 33 Test FN: 9
# sensitivity: 0.98 | specificity: 0.22 | g_mean: 0.47 | mcc: 0.31
# ADASYN over-sampling
# Train FP: 257 Train FN: 302; Test FP: 36 Test FN: 10
# Train FP: 271 Train FN: 281; Test FP: 35 Test FN: 8
# Train FP: 248 Train FN: 280; Test FP: 34 Test FN: 10
# Train FP: 238 Train FN: 260; Test FP: 26 Test FN: 8
# Train FP: 251 Train FN: 323; Test FP: 30 Test FN: 6
# Train FP: 265 Train FN: 298; Test FP: 18 Test FN: 9
# Train FP: 261 Train FN: 261; Test FP: 38 Test FN: 6
# Train FP: 252 Train FN: 267; Test FP: 34 Test FN: 5
# Train FP: 258 Train FN: 265; Test FP: 38 Test FN: 6
# Train FP: 249 Train FN: 308; Test FP: 36 Test FN: 9
# sensitivity: 0.98 | specificity: 0.22 | g_mean: 0.47 | mcc: 0.31
# Random under-sampling
# Train FP: 0 Train FN: 1; Test FP: 93 Test FN: 7
# Train FP: 3 Train FN: 2; Test FP: 104 Test FN: 4
# Train FP: 3 Train FN: 3; Test FP: 88 Test FN: 7
# Train FP: 1 Train FN: 2; Test FP: 125 Test FN: 3
# Train FP: 0 Train FN: 0; Test FP: 84 Test FN: 1
# Train FP: 2 Train FN: 3; Test FP: 86 Test FN: 2
# Train FP: 1 Train FN: 2; Test FP: 106 Test FN: 3
# Train FP: 2 Train FN: 1; Test FP: 82 Test FN: 4
# Train FP: 3 Train FN: 1; Test FP: 119 Test FN: 1
# Train FP: 0 Train FN: 1; Test FP: 100 Test FN: 2
# sensitivity: 0.99 | specificity: 0.12 | g_mean: 0.35 | mcc: 0.26
# ----------------------------------------------------------------------
#
# Classifier: ml
# Random over-sampling
# Train FP: 1250 Train FN: 1141; Test FP: 139 Test FN: 8
# Train FP: 1530 Train FN: 978; Test FP: 175 Test FN: 3
# Train FP: 1321 Train FN: 849; Test FP: 146 Test FN: 7
# Train FP: 1014 Train FN: 1384; Test FP: 134 Test FN: 9
# Train FP: 927 Train FN: 1462; Test FP: 111 Test FN: 9
# Train FP: 1276 Train FN: 1166; Test FP: 132 Test FN: 5
# Train FP: 1403 Train FN: 1031; Test FP: 164 Test FN: 5
# Train FP: 1480 Train FN: 1051; Test FP: 171 Test FN: 2
# Train FP: 1287 Train FN: 1140; Test FP: 135 Test FN: 7
# Train FP: 1044 Train FN: 1479; Test FP: 108 Test FN: 8
# sensitivity: 0.98 | specificity: 0.07 | g_mean: 0.26 | mcc: 0.13
# SMOTE over-sampling
# Train FP: 1140 Train FN: 1032; Test FP: 126 Test FN: 9
# Train FP: 1539 Train FN: 661; Test FP: 166 Test FN: 4
# Train FP: 1365 Train FN: 735; Test FP: 149 Test FN: 9
# Train FP: 1022 Train FN: 1162; Test FP: 131 Test FN: 7
# Train FP: 1767 Train FN: 489; Test FP: 205 Test FN: 5
# Train FP: 1273 Train FN: 1033; Test FP: 126 Test FN: 6
# Train FP: 1108 Train FN: 1104; Test FP: 136 Test FN: 7
# Train FP: 928 Train FN: 1448; Test FP: 117 Test FN: 7
# Train FP: 1081 Train FN: 1163; Test FP: 107 Test FN: 9
# Train FP: 1084 Train FN: 1227; Test FP: 128 Test FN: 7
# sensitivity: 0.98 | specificity: 0.07 | g_mean: 0.26 | mcc: 0.12
# ADASYN over-sampling
# Train FP: 1561 Train FN: 608; Test FP: 177 Test FN: 8
# Train FP: 1521 Train FN: 805; Test FP: 164 Test FN: 4
# Train FP: 1414 Train FN: 701; Test FP: 148 Test FN: 7
# Train FP: 872 Train FN: 1560; Test FP: 112 Test FN: 8
# Train FP: 1096 Train FN: 1218; Test FP: 124 Test FN: 9
# Train FP: 1351 Train FN: 968; Test FP: 134 Test FN: 2
# Train FP: 1242 Train FN: 1049; Test FP: 149 Test FN: 7
# Train FP: 1689 Train FN: 687; Test FP: 195 Test FN: 2
# Train FP: 1290 Train FN: 947; Test FP: 132 Test FN: 9
# Train FP: 1256 Train FN: 1081; Test FP: 152 Test FN: 5
# sensitivity: 0.98 | specificity: 0.07 | g_mean: 0.26 | mcc: 0.13
# Random under-sampling
# Train FP: 31 Train FN: 69; Test FP: 125 Test FN: 10
# Train FP: 50 Train FN: 49; Test FP: 199 Test FN: 5
# Train FP: 35 Train FN: 75; Test FP: 103 Test FN: 5
# Train FP: 54 Train FN: 50; Test FP: 162 Test FN: 5
# Train FP: 41 Train FN: 58; Test FP: 142 Test FN: 8
# Train FP: 51 Train FN: 47; Test FP: 160 Test FN: 6
# Train FP: 45 Train FN: 52; Test FP: 165 Test FN: 8
# Train FP: 50 Train FN: 56; Test FP: 142 Test FN: 8
# Train FP: 46 Train FN: 58; Test FP: 134 Test FN: 8
# Train FP: 40 Train FN: 58; Test FP: 150 Test FN: 10
# sensitivity: 0.98 | specificity: 0.06 | g_mean: 0.25 | mcc: 0.10
# ----------------------------------------------------------------------
#
# Classifier: bb
# Random over-sampling
# Train FP: 2 Train FN: 0; Test FP: 0 Test FN: 12
# Train FP: 1 Train FN: 0; Test FP: 1 Test FN: 11
# Train FP: 1 Train FN: 0; Test FP: 1 Test FN: 11
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 12
# Train FP: 1 Train FN: 0; Test FP: 1 Test FN: 10
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 10
# Train FP: 2 Train FN: 0; Test FP: 0 Test FN: 13
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 9
# Train FP: 2 Train FN: 0; Test FP: 0 Test FN: 12
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 12
# sensitivity: 0.98 | specificity: 0.94 | g_mean: 0.96 | mcc: 0.56
# SMOTE over-sampling
# Train FP: 0 Train FN: 0; Test FP: 4 Test FN: 11
# Train FP: 1 Train FN: 1; Test FP: 9 Test FN: 8
# Train FP: 0 Train FN: 1; Test FP: 13 Test FN: 10
# Train FP: 0 Train FN: 1; Test FP: 6 Test FN: 8
# Train FP: 2 Train FN: 2; Test FP: 6 Test FN: 9
# Train FP: 2 Train FN: 0; Test FP: 4 Test FN: 7
# Train FP: 3 Train FN: 0; Test FP: 5 Test FN: 12
# Train FP: 3 Train FN: 0; Test FP: 3 Test FN: 8
# Train FP: 2 Train FN: 0; Test FP: 8 Test FN: 9
# Train FP: 1 Train FN: 0; Test FP: 1 Test FN: 11
# sensitivity: 0.98 | specificity: 0.57 | g_mean: 0.75 | mcc: 0.49
# ADASYN over-sampling
# Train FP: 0 Train FN: 1; Test FP: 5 Test FN: 11
# Train FP: 1 Train FN: 0; Test FP: 8 Test FN: 9
# Train FP: 3 Train FN: 0; Test FP: 9 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 8
# Train FP: 2 Train FN: 0; Test FP: 4 Test FN: 8
# Train FP: 2 Train FN: 0; Test FP: 6 Test FN: 9
# Train FP: 4 Train FN: 1; Test FP: 5 Test FN: 11
# Train FP: 1 Train FN: 2; Test FP: 6 Test FN: 8
# Train FP: 2 Train FN: 1; Test FP: 7 Test FN: 10
# Train FP: 1 Train FN: 0; Test FP: 1 Test FN: 10
# sensitivity: 0.98 | specificity: 0.57 | g_mean: 0.75 | mcc: 0.49
# Random under-sampling
# Train FP: 0 Train FN: 3; Test FP: 107 Test FN: 3
# Train FP: 0 Train FN: 3; Test FP: 104 Test FN: 2
# Train FP: 1 Train FN: 2; Test FP: 136 Test FN: 2
# Train FP: 3 Train FN: 1; Test FP: 146 Test FN: 4
# Train FP: 2 Train FN: 2; Test FP: 160 Test FN: 5
# Train FP: 3 Train FN: 1; Test FP: 126 Test FN: 4
# Train FP: 0 Train FN: 1; Test FP: 115 Test FN: 2
# Train FP: 1 Train FN: 1; Test FP: 131 Test FN: 1
# Train FP: 4 Train FN: 1; Test FP: 120 Test FN: 2
# Train FP: 1 Train FN: 1; Test FP: 139 Test FN: 1
# sensitivity: 0.99 | specificity: 0.10 | g_mean: 0.32 | mcc: 0.23
# ----------------------------------------------------------------------
