# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# functions needed for pr_auc_score()
from sklearn.metrics import auc, precision_recall_curve
from sklearn import metrics

# functions needed for imbalanced_cross_validation_score()
from sklearn.model_selection import StratifiedKFold

# sampler objects
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler

# Classification models to compare
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB # naive bayes
from sklearn.neighbors import KNeighborsClassifier # KNN
from sklearn.svm import SVC # SVM

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
def pr_auc_score(clf, x, y):
    '''
        This function computes area under the precision-recall curve. 
    '''
      
    precisions, recalls,_ = precision_recall_curve(y, clf.predict_proba(x)[:,1], pos_label=1)
    
    return auc(recalls, precisions)

# %%
def FP_FN_score(clf, x, y):
    cm = metrics.confusion_matrix(y, clf.predict(x))
    FP = cm[0][1]
    FN = cm[1][0]
    return FP, FN

# %%
def imbalanced_cross_validation_score(clf, x, y, cv, scoring, sampler):
    '''
        This function computes the cross-validation score of a given 
        classifier using a choice of sampling function to mitigate 
        the class imbalance, and stratified k-fold sampling.
        
        The first five arguments are the same as 
        sklearn.model_selection.cross_val_score.
        
        - clf.predict_proba(x) returns class label probabilities
        - clf.fit(x,y) trains the model
        
        - x = data
        
        - y = labels
        
        - cv = the number of folds in the cross validation
        
        - scoring(classifier, x, y) returns a float
        
        The last argument is a choice of random sampler: an object 
        similar to the sampler objects available from the python 
        package imbalanced-learn. In particular, this 
        object needs to have the method:
        
        sampler.fit_sample(x,y)
        
        See http://contrib.scikit-learn.org/imbalanced-learn/
        for more details and examples of other sampling objects 
        available.  
    
    '''
    
    cv_score = 0.
    train_score = 0.
    test_score = 0.
    FP = 0
    FN = 0
    
    # stratified k-fold creates folds with the same ratio of positive 
    # and negative samples as the entire dataset.
    
    skf = StratifiedKFold(n_splits=cv, random_state=0, shuffle=False)
    
    for train_idx, test_idx in skf.split(x,y):
        
        xfold_train_sampled, yfold_train_sampled = sampler.fit_sample(x[train_idx],y[train_idx])
        clf.fit(xfold_train_sampled, yfold_train_sampled)
        
        FP_train, FN_train = scoring(clf, xfold_train_sampled, yfold_train_sampled)
        FP_test, FN_test  = scoring(clf, x[test_idx], y[test_idx])
        
        print("Train FP: {0} Train FN: {1}; Test FP: {2} Test FN: {3}".format(FP_train,FN_train, FP_test, FN_test))

        FP += FP_test
        FN += FN_test
        
    return FP/cv, FN/cv

# %%
x_train_o = pd.read_csv('financial_data.csv')
y_train_o = pd.read_csv('revealed_businesses.csv')

x_test_o = pd.read_csv("testing_data.csv")

x_train_o.replace('?', np.nan, inplace=True)
x_train_o = x_train_o.astype('float64')


x_test_o.replace('?', np.nan, inplace=True)
x_test_o = x_test_o.astype('float64')

data_all = x_train_o.merge(y_train_o, on='Var1', how = 'left')

data_nolabel = data_all[data_all.Var66.isnull()]
data_label = data_all[data_all.Var66.notnull()]

data_nolabel_v = data_nolabel.drop(columns=['Var1', 'Var66'])
data_nolabel_id = data_nolabel['Var1']

data_label_v = data_label.drop(columns=['Var1', 'Var66'])
data_label_id = data_label['Var1']

data_nolabel_v_f = data_nolabel_v.fillna(data_nolabel_v.mean())
data_label_v_f = data_label_v.fillna(data_label_v.mean())

# %%
x = data_label_v_f.values
y = data_label['Var66'].values

# %%
clfs={
    'gnb': GaussianNB(),
    'svm': SVC(),
    'lr':  LogisticRegression(),
    'rfc': RandomForestClassifier(),
    'et': ExtraTreesClassifier(),
    'ada': AdaBoostClassifier(),
    'ml': MLPClassifier()
}
cv = 5
for clf_name in clfs:
    print("Classifier: {0}".format(clf_name))
    # Logistic regression score with Random Over-sampling
    print("Random over-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, RandomOverSampler())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))

    # Logistic regression score with SMOTE
    print("SMOTE over-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, SMOTE())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))

    # Logistic regression score with ADASYN
    print("ADASYN over-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, ADASYN())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))

    # Logistic regression score with Random Under Sampling
    print("Random under-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, RandomUnderSampler())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))
# Out:
# Classifier: gnb
# Random over-sampling
# Train FP: 3507 Train FN: 117; Test FP: 867 Test FN: 1
# Train FP: 3399 Train FN: 28; Test FP: 849 Test FN: 2
# Train FP: 3406 Train FN: 84; Test FP: 873 Test FN: 3
# Train FP: 3368 Train FN: 79; Test FP: 843 Test FN: 3
# Train FP: 3461 Train FN: 25; Test FP: 875 Test FN: 4
# average FP: 861.40 average FN: 2.60
# SMOTE over-sampling
# Train FP: 3424 Train FN: 87; Test FP: 847 Test FN: 1
# Train FP: 3327 Train FN: 72; Test FP: 833 Test FN: 2
# Train FP: 3337 Train FN: 56; Test FP: 859 Test FN: 3
# Train FP: 3305 Train FN: 74; Test FP: 822 Test FN: 3
# Train FP: 3387 Train FN: 46; Test FP: 853 Test FN: 5
# average FP: 842.80 average FN: 2.80
# ADASYN over-sampling
# Train FP: 3432 Train FN: 71; Test FP: 850 Test FN: 1
# Train FP: 3319 Train FN: 71; Test FP: 834 Test FN: 2
# Train FP: 3342 Train FN: 64; Test FP: 858 Test FN: 3
# Train FP: 3308 Train FN: 61; Test FP: 823 Test FN: 3
# Train FP: 3393 Train FN: 43; Test FP: 853 Test FN: 4
# average FP: 843.60 average FN: 2.60
# Random under-sampling
# Train FP: 5 Train FN: 115; Test FP: 120 Test FN: 29
# Train FP: 4 Train FN: 116; Test FP: 88 Test FN: 31
# Train FP: 12 Train FN: 121; Test FP: 69 Test FN: 32
# Train FP: 95 Train FN: 9; Test FP: 716 Test FN: 5
# Train FP: 103 Train FN: 7; Test FP: 808 Test FN: 5
# average FP: 360.20 average FN: 20.40
# Classifier: svm
# Random over-sampling
# Train FP: 1 Train FN: 0; Test FP: 1 Test FN: 34
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 34
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 34
# Train FP: 2 Train FN: 0; Test FP: 0 Test FN: 34
# Train FP: 2 Train FN: 0; Test FP: 0 Test FN: 34
# average FP: 0.40 average FN: 34.00
# SMOTE over-sampling
# Train FP: 0 Train FN: 1; Test FP: 1 Test FN: 34
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 34
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 34
# Train FP: 0 Train FN: 1; Test FP: 0 Test FN: 34
# Train FP: 2 Train FN: 0; Test FP: 0 Test FN: 34
# average FP: 0.40 average FN: 34.00
# ADASYN over-sampling
# Train FP: 0 Train FN: 1; Test FP: 1 Test FN: 34
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 34
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 34
# Train FP: 0 Train FN: 1; Test FP: 0 Test FN: 34
# Train FP: 1 Train FN: 0; Test FP: 0 Test FN: 34
# average FP: 0.40 average FN: 34.00
# Random under-sampling
# Train FP: 0 Train FN: 0; Test FP: 872 Test FN: 1
# Train FP: 0 Train FN: 0; Test FP: 882 Test FN: 0
# Train FP: 0 Train FN: 0; Test FP: 871 Test FN: 1
# Train FP: 0 Train FN: 0; Test FP: 876 Test FN: 1
# Train FP: 0 Train FN: 0; Test FP: 874 Test FN: 0
# average FP: 875.00 average FN: 0.60
# Classifier: lr
# Random over-sampling
# Train FP: 252 Train FN: 2983; Test FP: 60 Test FN: 29
# Train FP: 225 Train FN: 3026; Test FP: 58 Test FN: 31
# Train FP: 2313 Train FN: 736; Test FP: 580 Test FN: 8
# Train FP: 728 Train FN: 2280; Test FP: 183 Test FN: 25
# Train FP: 201 Train FN: 3277; Test FP: 48 Test FN: 31
# average FP: 185.80 average FN: 24.80
# SMOTE over-sampling
# Train FP: 255 Train FN: 3115; Test FP: 62 Test FN: 28
# Train FP: 362 Train FN: 2909; Test FP: 77 Test FN: 28
# Train FP: 2043 Train FN: 732; Test FP: 516 Test FN: 12
# Train FP: 531 Train FN: 2693; Test FP: 136 Test FN: 26
# Train FP: 242 Train FN: 3242; Test FP: 56 Test FN: 31
# average FP: 169.40 average FN: 25.00
# ADASYN over-sampling
# Train FP: 240 Train FN: 3037; Test FP: 62 Test FN: 30
# Train FP: 274 Train FN: 3003; Test FP: 64 Test FN: 29
# Train FP: 1048 Train FN: 1441; Test FP: 287 Test FN: 16
# Train FP: 796 Train FN: 2097; Test FP: 203 Test FN: 23
# Train FP: 308 Train FN: 3096; Test FP: 72 Test FN: 28
# average FP: 137.60 average FN: 25.20
# Random under-sampling
# Train FP: 18 Train FN: 27; Test FP: 236 Test FN: 10
# Train FP: 17 Train FN: 33; Test FP: 121 Test FN: 8
# Train FP: 21 Train FN: 77; Test FP: 224 Test FN: 23
# Train FP: 19 Train FN: 27; Test FP: 158 Test FN: 11
# Train FP: 24 Train FN: 43; Test FP: 252 Test FN: 11
# average FP: 198.20 average FN: 12.60
# Classifier: rfc
# Random over-sampling
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 24
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 26
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 23
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 23
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 22
# average FP: 1.20 average FN: 23.60
# SMOTE over-sampling
# Train FP: 0 Train FN: 0; Test FP: 12 Test FN: 20
# Train FP: 0 Train FN: 0; Test FP: 10 Test FN: 24
# Train FP: 4 Train FN: 2; Test FP: 16 Test FN: 22
# Train FP: 1 Train FN: 3; Test FP: 9 Test FN: 22
# Train FP: 1 Train FN: 0; Test FP: 9 Test FN: 24
# average FP: 11.20 average FN: 22.40
# ADASYN over-sampling
# Train FP: 1 Train FN: 1; Test FP: 12 Test FN: 21
# Train FP: 0 Train FN: 1; Test FP: 12 Test FN: 20
# Train FP: 0 Train FN: 0; Test FP: 13 Test FN: 19
# Train FP: 2 Train FN: 0; Test FP: 9 Test FN: 22
# Train FP: 1 Train FN: 0; Test FP: 8 Test FN: 27
# average FP: 10.80 average FN: 21.80
# Random under-sampling
# Train FP: 1 Train FN: 2; Test FP: 167 Test FN: 10
# Train FP: 1 Train FN: 4; Test FP: 247 Test FN: 5
# Train FP: 0 Train FN: 2; Test FP: 191 Test FN: 9
# Train FP: 0 Train FN: 4; Test FP: 227 Test FN: 12
# Train FP: 0 Train FN: 1; Test FP: 206 Test FN: 11
# average FP: 207.60 average FN: 9.40
# Classifier: et
# Random over-sampling
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 33
# Train FP: 0 Train FN: 0; Test FP: 3 Test FN: 32
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 33
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 31
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 30
# average FP: 1.40 average FN: 31.80
# SMOTE over-sampling
# Train FP: 0 Train FN: 0; Test FP: 16 Test FN: 26
# Train FP: 0 Train FN: 0; Test FP: 20 Test FN: 29
# Train FP: 0 Train FN: 0; Test FP: 9 Test FN: 21
# Train FP: 0 Train FN: 0; Test FP: 11 Test FN: 24
# Train FP: 0 Train FN: 0; Test FP: 6 Test FN: 29
# average FP: 12.40 average FN: 25.80
# ADASYN over-sampling
# Train FP: 0 Train FN: 0; Test FP: 12 Test FN: 24
# Train FP: 0 Train FN: 0; Test FP: 20 Test FN: 25
# Train FP: 0 Train FN: 0; Test FP: 17 Test FN: 21
# Train FP: 0 Train FN: 0; Test FP: 9 Test FN: 25
# Train FP: 0 Train FN: 0; Test FP: 7 Test FN: 27
# average FP: 13.00 average FN: 24.40
# Random under-sampling
# Train FP: 0 Train FN: 0; Test FP: 186 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 200 Test FN: 10
# Train FP: 0 Train FN: 0; Test FP: 187 Test FN: 10
# Train FP: 0 Train FN: 0; Test FP: 198 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 213 Test FN: 9
# average FP: 196.80 average FN: 9.40
# Classifier: ada
# Random over-sampling
# Train FP: 281 Train FN: 155; Test FP: 78 Test FN: 13
# Train FP: 240 Train FN: 100; Test FP: 63 Test FN: 14
# Train FP: 262 Train FN: 180; Test FP: 73 Test FN: 13
# Train FP: 268 Train FN: 81; Test FP: 71 Test FN: 12
# Train FP: 286 Train FN: 230; Test FP: 79 Test FN: 13
# average FP: 72.80 average FN: 13.00
# SMOTE over-sampling
# Train FP: 241 Train FN: 195; Test FP: 73 Test FN: 13
# Train FP: 201 Train FN: 161; Test FP: 62 Test FN: 15
# Train FP: 231 Train FN: 218; Test FP: 43 Test FN: 15
# Train FP: 210 Train FN: 212; Test FP: 66 Test FN: 15
# Train FP: 217 Train FN: 199; Test FP: 65 Test FN: 17
# average FP: 61.80 average FN: 15.00
# ADASYN over-sampling
# Train FP: 227 Train FN: 184; Test FP: 65 Test FN: 16
# Train FP: 195 Train FN: 167; Test FP: 63 Test FN: 15
# Train FP: 228 Train FN: 188; Test FP: 55 Test FN: 15
# Train FP: 209 Train FN: 173; Test FP: 70 Test FN: 18
# Train FP: 245 Train FN: 204; Test FP: 57 Test FN: 15
# average FP: 62.00 average FN: 15.80
# Random under-sampling
# Train FP: 1 Train FN: 0; Test FP: 169 Test FN: 8
# Train FP: 0 Train FN: 0; Test FP: 211 Test FN: 10
# Train FP: 0 Train FN: 0; Test FP: 215 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 191 Test FN: 9
# Train FP: 0 Train FN: 2; Test FP: 200 Test FN: 5
# average FP: 197.20 average FN: 8.20
# Classifier: ml
# Random over-sampling
# Train FP: 415 Train FN: 840; Test FP: 105 Test FN: 20
# Train FP: 447 Train FN: 966; Test FP: 145 Test FN: 22
# Train FP: 1659 Train FN: 315; Test FP: 431 Test FN: 7
# Train FP: 721 Train FN: 478; Test FP: 203 Test FN: 8
# Train FP: 845 Train FN: 580; Test FP: 224 Test FN: 11
# average FP: 221.60 average FN: 13.60
# SMOTE over-sampling
# Train FP: 830 Train FN: 330; Test FP: 217 Test FN: 17
# Train FP: 849 Train FN: 348; Test FP: 212 Test FN: 16
# Train FP: 372 Train FN: 1536; Test FP: 88 Test FN: 15
# Train FP: 210 Train FN: 1552; Test FP: 81 Test FN: 23
# Train FP: 1014 Train FN: 181; Test FP: 271 Test FN: 9
# average FP: 173.80 average FN: 16.00
# ADASYN over-sampling
# Train FP: 690 Train FN: 662; Test FP: 193 Test FN: 19
# Train FP: 716 Train FN: 418; Test FP: 194 Test FN: 16
# Train FP: 1286 Train FN: 159; Test FP: 312 Test FN: 7
# Train FP: 552 Train FN: 885; Test FP: 146 Test FN: 14
# Train FP: 508 Train FN: 468; Test FP: 129 Test FN: 16
# average FP: 194.80 average FN: 14.40
# Random under-sampling
# Train FP: 34 Train FN: 33; Test FP: 324 Test FN: 13
# Train FP: 16 Train FN: 43; Test FP: 207 Test FN: 21
# Train FP: 58 Train FN: 47; Test FP: 446 Test FN: 15
# Train FP: 17 Train FN: 49; Test FP: 237 Test FN: 16
# Train FP: 78 Train FN: 50; Test FP: 524 Test FN: 17
# average FP: 347.60 average FN: 16.40
