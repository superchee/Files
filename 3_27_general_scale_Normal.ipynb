# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# functions needed for pr_auc_score()
from sklearn.metrics import auc, precision_recall_curve
from sklearn import metrics

# functions needed for imbalanced_cross_validation_score()
from sklearn.model_selection import StratifiedKFold

# sampler objects
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler

# Classification models to compare
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB # naive bayes
from sklearn.neighbors import KNeighborsClassifier # KNN
from sklearn.svm import SVC # SVM

from sklearn import preprocessing 

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
def pr_auc_score(clf, x, y):
    '''
        This function computes area under the precision-recall curve. 
    '''
      
    precisions, recalls,_ = precision_recall_curve(y, clf.predict_proba(x)[:,1], pos_label=1)
    
    return auc(recalls, precisions)

# %%
def FP_FN_score(clf, x, y):
    cm = metrics.confusion_matrix(y, clf.predict(x))
    FP = cm[0][1]
    FN = cm[1][0]
    return FP, FN

# %%
def imbalanced_cross_validation_score(clf, x, y, cv, scoring, sampler):
    '''
        This function computes the cross-validation score of a given 
        classifier using a choice of sampling function to mitigate 
        the class imbalance, and stratified k-fold sampling.
        
        The first five arguments are the same as 
        sklearn.model_selection.cross_val_score.
        
        - clf.predict_proba(x) returns class label probabilities
        - clf.fit(x,y) trains the model
        
        - x = data
        
        - y = labels
        
        - cv = the number of folds in the cross validation
        
        - scoring(classifier, x, y) returns a float
        
        The last argument is a choice of random sampler: an object 
        similar to the sampler objects available from the python 
        package imbalanced-learn. In particular, this 
        object needs to have the method:
        
        sampler.fit_sample(x,y)
        
        See http://contrib.scikit-learn.org/imbalanced-learn/
        for more details and examples of other sampling objects 
        available.  
    
    '''
    
    cv_score = 0.
    train_score = 0.
    test_score = 0.
    FP = 0
    FN = 0
    
    # stratified k-fold creates folds with the same ratio of positive 
    # and negative samples as the entire dataset.
    
    skf = StratifiedKFold(n_splits=cv, random_state=0, shuffle=False)
    
    for train_idx, test_idx in skf.split(x,y):
        
        xfold_train_sampled, yfold_train_sampled = sampler.fit_sample(x[train_idx],y[train_idx])
        clf.fit(xfold_train_sampled, yfold_train_sampled)
        
        FP_train, FN_train = scoring(clf, xfold_train_sampled, yfold_train_sampled)
        FP_test, FN_test  = scoring(clf, x[test_idx], y[test_idx])
        
        print("Train FP: {0} Train FN: {1}; Test FP: {2} Test FN: {3}".format(FP_train,FN_train, FP_test, FN_test))

        FP += FP_test
        FN += FN_test
        
    return FP/cv, FN/cv

# %%
x_train_o = pd.read_csv('financial_data.csv')
y_train_o = pd.read_csv('revealed_businesses.csv')

x_test_o = pd.read_csv("testing_data.csv")

x_train_o.replace('?', np.nan, inplace=True)
x_train_o = x_train_o.astype('float64')


x_test_o.replace('?', np.nan, inplace=True)
x_test_o = x_test_o.astype('float64')

data_all = x_train_o.merge(y_train_o, on='Var1', how = 'left')

data_nolabel = data_all[data_all.Var66.isnull()]
data_label = data_all[data_all.Var66.notnull()]

data_nolabel_v = data_nolabel.drop(columns=['Var1', 'Var66'])
data_nolabel_id = data_nolabel['Var1']

data_label_v = data_label.drop(columns=['Var1', 'Var66'])
data_label_id = data_label['Var1']

data_nolabel_v_f = data_nolabel_v.fillna(data_nolabel_v.mean())
data_label_v_f = data_label_v.fillna(data_label_v.mean())

# %%
X = data_label_v_f.values
y = data_label['Var66'].values

# %%
x = preprocessing.Normalizer().fit_transform(X)

# %%
clfs={
    'gnb': GaussianNB(),
    'svm': SVC(),
    'lr':  LogisticRegression(),
    'rfc': RandomForestClassifier(),
    'et': ExtraTreesClassifier(),
    'ada': AdaBoostClassifier(),
    'ml': MLPClassifier()
}
cv = 5
for clf_name in clfs:
    print("Classifier: {0}".format(clf_name))
    # Logistic regression score with Random Over-sampling
    print("Random over-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, RandomOverSampler())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))

    # Logistic regression score with SMOTE
    print("SMOTE over-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, SMOTE())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))

    # Logistic regression score with ADASYN
    print("ADASYN over-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, ADASYN())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))

    # Logistic regression score with Random Under Sampling
    print("Random under-sampling")
    FP, FN = imbalanced_cross_validation_score(clfs[clf_name], x, y, cv, FP_FN_score, RandomUnderSampler())
    print("average FP: %.2f average FN: %.2f "%(FP, FN))
# Out:
# Classifier: gnb
# Random over-sampling
# Train FP: 2889 Train FN: 389; Test FP: 709 Test FN: 6
# Train FP: 2811 Train FN: 377; Test FP: 722 Test FN: 7
# Train FP: 2889 Train FN: 389; Test FP: 746 Test FN: 5
# Train FP: 3012 Train FN: 215; Test FP: 753 Test FN: 4
# Train FP: 2913 Train FN: 368; Test FP: 710 Test FN: 2
# average FP: 728.00 average FN: 4.80
# SMOTE over-sampling
# Train FP: 2831 Train FN: 294; Test FP: 691 Test FN: 8
# Train FP: 2788 Train FN: 273; Test FP: 712 Test FN: 7
# Train FP: 2804 Train FN: 327; Test FP: 734 Test FN: 6
# Train FP: 2918 Train FN: 311; Test FP: 725 Test FN: 4
# Train FP: 2861 Train FN: 372; Test FP: 696 Test FN: 3
# average FP: 711.60 average FN: 5.60
# ADASYN over-sampling
# Train FP: 2827 Train FN: 315; Test FP: 694 Test FN: 8
# Train FP: 2820 Train FN: 296; Test FP: 722 Test FN: 7
# Train FP: 2828 Train FN: 347; Test FP: 737 Test FN: 6
# Train FP: 2945 Train FN: 316; Test FP: 735 Test FN: 4
# Train FP: 2892 Train FN: 373; Test FP: 702 Test FN: 3
# average FP: 718.00 average FN: 5.60
# Random under-sampling
# Train FP: 73 Train FN: 12; Test FP: 514 Test FN: 7
# Train FP: 97 Train FN: 9; Test FP: 648 Test FN: 4
# Train FP: 11 Train FN: 96; Test FP: 78 Test FN: 28
# Train FP: 14 Train FN: 95; Test FP: 173 Test FN: 26
# Train FP: 4 Train FN: 108; Test FP: 94 Test FN: 32
# average FP: 301.40 average FN: 19.40
# Classifier: svm
# Random over-sampling
# Train FP: 946 Train FN: 1764; Test FP: 243 Test FN: 14
# Train FP: 879 Train FN: 1718; Test FP: 201 Test FN: 21
# Train FP: 955 Train FN: 1970; Test FP: 256 Test FN: 15
# Train FP: 936 Train FN: 1819; Test FP: 241 Test FN: 17
# Train FP: 1101 Train FN: 1652; Test FP: 279 Test FN: 16
# average FP: 244.00 average FN: 16.60
# SMOTE over-sampling
# Train FP: 1002 Train FN: 1837; Test FP: 261 Test FN: 14
# Train FP: 891 Train FN: 1789; Test FP: 209 Test FN: 21
# Train FP: 1010 Train FN: 2014; Test FP: 266 Test FN: 13
# Train FP: 975 Train FN: 1806; Test FP: 246 Test FN: 18
# Train FP: 917 Train FN: 1841; Test FP: 220 Test FN: 17
# average FP: 240.40 average FN: 16.60
# ADASYN over-sampling
# Train FP: 966 Train FN: 1909; Test FP: 260 Test FN: 14
# Train FP: 926 Train FN: 1902; Test FP: 212 Test FN: 21
# Train FP: 1254 Train FN: 1687; Test FP: 313 Test FN: 11
# Train FP: 1044 Train FN: 1696; Test FP: 266 Test FN: 19
# Train FP: 1045 Train FN: 1873; Test FP: 263 Test FN: 19
# average FP: 262.80 average FN: 16.80
# Random under-sampling
# Train FP: 30 Train FN: 81; Test FP: 241 Test FN: 17
# Train FP: 27 Train FN: 78; Test FP: 199 Test FN: 23
# Train FP: 35 Train FN: 83; Test FP: 240 Test FN: 19
# Train FP: 25 Train FN: 80; Test FP: 206 Test FN: 19
# Train FP: 32 Train FN: 77; Test FP: 206 Test FN: 23
# average FP: 218.40 average FN: 20.20
# Classifier: lr
# Random over-sampling
# Train FP: 1014 Train FN: 1588; Test FP: 264 Test FN: 14
# Train FP: 979 Train FN: 1648; Test FP: 229 Test FN: 22
# Train FP: 1083 Train FN: 1679; Test FP: 285 Test FN: 12
# Train FP: 1015 Train FN: 1481; Test FP: 247 Test FN: 18
# Train FP: 1013 Train FN: 1542; Test FP: 262 Test FN: 15
# average FP: 257.40 average FN: 16.20
# SMOTE over-sampling
# Train FP: 1086 Train FN: 1490; Test FP: 295 Test FN: 11
# Train FP: 979 Train FN: 1580; Test FP: 233 Test FN: 21
# Train FP: 1187 Train FN: 1482; Test FP: 294 Test FN: 12
# Train FP: 972 Train FN: 1699; Test FP: 241 Test FN: 17
# Train FP: 1013 Train FN: 1727; Test FP: 253 Test FN: 15
# average FP: 263.20 average FN: 15.20
# ADASYN over-sampling
# Train FP: 1084 Train FN: 1664; Test FP: 291 Test FN: 13
# Train FP: 1037 Train FN: 1708; Test FP: 245 Test FN: 22
# Train FP: 1284 Train FN: 1338; Test FP: 311 Test FN: 12
# Train FP: 1072 Train FN: 1595; Test FP: 268 Test FN: 20
# Train FP: 1081 Train FN: 1675; Test FP: 279 Test FN: 14
# average FP: 278.80 average FN: 16.20
# Random under-sampling
# Train FP: 38 Train FN: 62; Test FP: 295 Test FN: 14
# Train FP: 39 Train FN: 59; Test FP: 214 Test FN: 21
# Train FP: 38 Train FN: 66; Test FP: 307 Test FN: 12
# Train FP: 43 Train FN: 57; Test FP: 261 Test FN: 16
# Train FP: 33 Train FN: 57; Test FP: 287 Test FN: 15
# average FP: 272.80 average FN: 15.60
# Classifier: rfc
# Random over-sampling
# Train FP: 0 Train FN: 0; Test FP: 2 Test FN: 28
# Train FP: 0 Train FN: 0; Test FP: 3 Test FN: 27
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 26
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 25
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 28
# average FP: 1.40 average FN: 26.80
# SMOTE over-sampling
# Train FP: 3 Train FN: 2; Test FP: 21 Test FN: 21
# Train FP: 0 Train FN: 0; Test FP: 22 Test FN: 19
# Train FP: 0 Train FN: 4; Test FP: 17 Test FN: 16
# Train FP: 2 Train FN: 1; Test FP: 12 Test FN: 19
# Train FP: 0 Train FN: 1; Test FP: 15 Test FN: 23
# average FP: 17.40 average FN: 19.60
# ADASYN over-sampling
# Train FP: 1 Train FN: 1; Test FP: 21 Test FN: 22
# Train FP: 0 Train FN: 0; Test FP: 23 Test FN: 21
# Train FP: 0 Train FN: 0; Test FP: 29 Test FN: 18
# Train FP: 2 Train FN: 0; Test FP: 17 Test FN: 20
# Train FP: 2 Train FN: 1; Test FP: 15 Test FN: 24
# average FP: 21.00 average FN: 21.00
# Random under-sampling
# Train FP: 0 Train FN: 4; Test FP: 176 Test FN: 13
# Train FP: 1 Train FN: 2; Test FP: 187 Test FN: 14
# Train FP: 0 Train FN: 3; Test FP: 263 Test FN: 12
# Train FP: 0 Train FN: 3; Test FP: 239 Test FN: 12
# Train FP: 0 Train FN: 1; Test FP: 183 Test FN: 17
# average FP: 209.60 average FN: 13.60
# Classifier: et
# Random over-sampling
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 34
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 32
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 31
# Train FP: 0 Train FN: 0; Test FP: 0 Test FN: 30
# Train FP: 0 Train FN: 0; Test FP: 1 Test FN: 33
# average FP: 0.80 average FN: 32.00
# SMOTE over-sampling
# Train FP: 0 Train FN: 0; Test FP: 16 Test FN: 29
# Train FP: 0 Train FN: 0; Test FP: 24 Test FN: 24
# Train FP: 0 Train FN: 0; Test FP: 20 Test FN: 24
# Train FP: 0 Train FN: 0; Test FP: 7 Test FN: 25
# Train FP: 0 Train FN: 0; Test FP: 12 Test FN: 33
# average FP: 15.80 average FN: 27.00
# ADASYN over-sampling
# Train FP: 0 Train FN: 0; Test FP: 22 Test FN: 30
# Train FP: 0 Train FN: 0; Test FP: 16 Test FN: 26
# Train FP: 0 Train FN: 0; Test FP: 13 Test FN: 23
# Train FP: 0 Train FN: 0; Test FP: 11 Test FN: 26
# Train FP: 0 Train FN: 0; Test FP: 18 Test FN: 28
# average FP: 16.00 average FN: 26.60
# Random under-sampling
# Train FP: 0 Train FN: 0; Test FP: 219 Test FN: 13
# Train FP: 0 Train FN: 0; Test FP: 230 Test FN: 18
# Train FP: 0 Train FN: 0; Test FP: 206 Test FN: 16
# Train FP: 0 Train FN: 0; Test FP: 287 Test FN: 9
# Train FP: 0 Train FN: 0; Test FP: 203 Test FN: 10
# average FP: 229.00 average FN: 13.20
# Classifier: ada
# Random over-sampling
# Train FP: 281 Train FN: 230; Test FP: 77 Test FN: 14
# Train FP: 267 Train FN: 149; Test FP: 88 Test FN: 15
# Train FP: 329 Train FN: 106; Test FP: 86 Test FN: 12
# Train FP: 317 Train FN: 192; Test FP: 83 Test FN: 9
# Train FP: 303 Train FN: 237; Test FP: 94 Test FN: 17
# average FP: 85.60 average FN: 13.40
# SMOTE over-sampling
# Train FP: 235 Train FN: 218; Test FP: 79 Test FN: 16
# Train FP: 276 Train FN: 261; Test FP: 90 Test FN: 15
# Train FP: 288 Train FN: 220; Test FP: 85 Test FN: 10
# Train FP: 297 Train FN: 241; Test FP: 81 Test FN: 8
# Train FP: 317 Train FN: 265; Test FP: 76 Test FN: 16
# average FP: 82.20 average FN: 13.00
# ADASYN over-sampling
# Train FP: 274 Train FN: 235; Test FP: 91 Test FN: 16
# Train FP: 300 Train FN: 266; Test FP: 98 Test FN: 16
# Train FP: 299 Train FN: 192; Test FP: 77 Test FN: 11
# Train FP: 317 Train FN: 235; Test FP: 77 Test FN: 11
# Train FP: 316 Train FN: 237; Test FP: 87 Test FN: 12
# average FP: 86.00 average FN: 13.20
# Random under-sampling
# Train FP: 0 Train FN: 2; Test FP: 193 Test FN: 9
# Train FP: 1 Train FN: 1; Test FP: 237 Test FN: 9
# Train FP: 0 Train FN: 2; Test FP: 216 Test FN: 8
# Train FP: 2 Train FN: 0; Test FP: 171 Test FN: 10
# Train FP: 0 Train FN: 0; Test FP: 208 Test FN: 7
# average FP: 205.00 average FN: 8.60
# Classifier: ml
# Random over-sampling
# Train FP: 447 Train FN: 254; Test FP: 116 Test FN: 16
# Train FP: 526 Train FN: 283; Test FP: 167 Test FN: 19
# Train FP: 664 Train FN: 226; Test FP: 152 Test FN: 8
# Train FP: 481 Train FN: 349; Test FP: 131 Test FN: 12
# Train FP: 436 Train FN: 363; Test FP: 130 Test FN: 13
# average FP: 139.20 average FN: 13.60
# SMOTE over-sampling
# Train FP: 447 Train FN: 202; Test FP: 122 Test FN: 17
# Train FP: 473 Train FN: 242; Test FP: 152 Test FN: 19
# Train FP: 542 Train FN: 258; Test FP: 141 Test FN: 10
# Train FP: 442 Train FN: 260; Test FP: 105 Test FN: 11
# Train FP: 459 Train FN: 242; Test FP: 132 Test FN: 14
# average FP: 130.40 average FN: 14.20
# ADASYN over-sampling
# Train FP: 445 Train FN: 273; Test FP: 120 Test FN: 17
# Train FP: 542 Train FN: 176; Test FP: 164 Test FN: 21
# Train FP: 504 Train FN: 319; Test FP: 124 Test FN: 11
# Train FP: 554 Train FN: 222; Test FP: 130 Test FN: 12
# Train FP: 457 Train FN: 253; Test FP: 125 Test FN: 11
# average FP: 132.60 average FN: 14.40
# Random under-sampling
# Train FP: 32 Train FN: 43; Test FP: 305 Test FN: 9
# Train FP: 34 Train FN: 31; Test FP: 322 Test FN: 12
# Train FP: 40 Train FN: 31; Test FP: 305 Test FN: 7
# Train FP: 39 Train FN: 29; Test FP: 263 Test FN: 9
# Train FP: 29 Train FN: 37; Test FP: 238 Test FN: 11
# average FP: 286.60 average FN: 9.60
